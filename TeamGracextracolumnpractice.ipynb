# %% [markdown]
# <a href="https://colab.research.google.com/github/Taha-Mukati/TEAM_GRACE/blob/main/TeamGracextracolumnpractice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
data_filename = 'traffic_accidents.csv'

# %%
import pandas as pd

# %%
df = pd.read_csv(data_filename)

# %%
df
# Out:
#                     crash_date traffic_control_device weather_condition  \
# 0       07/29/2023 01:00:00 PM         TRAFFIC SIGNAL             CLEAR
# 1       08/13/2023 12:11:00 AM         TRAFFIC SIGNAL             CLEAR
# 2       12/09/2021 10:30:00 AM         TRAFFIC SIGNAL             CLEAR
# 3       08/09/2023 07:55:00 PM         TRAFFIC SIGNAL             CLEAR
# 4       08/19/2023 02:55:00 PM         TRAFFIC SIGNAL             CLEAR
# ...                        ...                    ...               ...
# 209301  09/13/2023 01:08:00 PM                UNKNOWN           UNKNOWN
# 209302  07/18/2023 02:10:00 PM                UNKNOWN             CLEAR
# 209303  10/23/2019 01:32:00 PM         TRAFFIC SIGNAL             CLEAR
# 209304  06/01/2020 03:23:00 PM            NO CONTROLS             CLEAR
# 209305  12/16/2022 12:10:00 PM         TRAFFIC SIGNAL             CLEAR
#
#             lighting_condition          first_crash_type  \
# ...

# %%
df.columns
# Out:
# Index(['crash_date', 'traffic_control_device', 'weather_condition',
#        'lighting_condition', 'first_crash_type', 'trafficway_type',
#        'alignment', 'roadway_surface_cond', 'road_defect', 'crash_type',
#        'intersection_related_i', 'damage', 'prim_contributory_cause',
#        'num_units', 'most_severe_injury', 'injuries_total', 'injuries_fatal',
#        'injuries_incapacitating', 'injuries_non_incapacitating',
#        'injuries_reported_not_evident', 'injuries_no_indication', 'crash_hour',
#        'crash_day_of_week', 'crash_month'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209306 entries, 0 to 209305
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   crash_date                     209306 non-null  object
#  1   traffic_control_device         209306 non-null  object
#  2   weather_condition              209306 non-null  object
#  3   lighting_condition             209306 non-null  object
#  4   first_crash_type               209306 non-null  object
#  5   trafficway_type                209306 non-null  object
#  6   alignment                      209306 non-null  object
#  7   roadway_surface_cond           209306 non-null  object
#  8   road_defect                    209306 non-null  object
#  9   crash_type                     209306 non-null  object
#  10  intersection_related_i         209306 non-null  object
#  11  damage                         209306 non-null  object
# ...

# %%
df.describe()
# Out:
#            num_units  injuries_total  injuries_fatal  injuries_incapacitating  \
# count  209306.000000   209306.000000   209306.000000            209306.000000
# mean        2.063300        0.382717        0.001859                 0.038102
# std         0.396012        0.799720        0.047502                 0.233964
# min         1.000000        0.000000        0.000000                 0.000000
# 25%         2.000000        0.000000        0.000000                 0.000000
# 50%         2.000000        0.000000        0.000000                 0.000000
# 75%         2.000000        1.000000        0.000000                 0.000000
# max        11.000000       21.000000        3.000000                 7.000000
#
#        injuries_non_incapacitating  injuries_reported_not_evident  \
# count                209306.000000                  209306.000000
# mean                      0.221241                       0.121516
# std                       0.614960                       0.450865
# ...

# %%
df.isna()
# Out:
#         crash_date  traffic_control_device  weather_condition  \
# 0            False                   False              False
# 1            False                   False              False
# 2            False                   False              False
# 3            False                   False              False
# 4            False                   False              False
# ...            ...                     ...                ...
# 209301       False                   False              False
# 209302       False                   False              False
# 209303       False                   False              False
# 209304       False                   False              False
# 209305       False                   False              False
#
#         lighting_condition  first_crash_type  trafficway_type  alignment  \
# 0                    False             False            False      False
# ...

# %%
df.weather_condition
# Out:
# 0           CLEAR
# 1           CLEAR
# 2           CLEAR
# 3           CLEAR
# 4           CLEAR
#            ...
# 209301    UNKNOWN
# 209302      CLEAR
# 209303      CLEAR
# 209304      CLEAR
# 209305      CLEAR
# Name: weather_condition, Length: 209306, dtype: object

# %%
weather_condition_accidents = df.weather_condition.value_counts()

# %%
weather_condition_accidents
len(weather_condition_accidents)
# Out:
# 12

# %%
lighting_condition_accidents = df.lighting_condition.value_counts()

# %%
lighting_condition_accidents
# Out:
# lighting_condition
# DAYLIGHT                  134109
# DARKNESS, LIGHTED ROAD     53378
# DARKNESS                    7436
# DUSK                        6323
# UNKNOWN                     4336
# DAWN                        3724
# Name: count, dtype: int64

# %%
len(lighting_condition_accidents)
# Out:
# 6

# %%
first_crash_types = df.crash_type.value_counts()

# %%
first_crash_types
# Out:
# crash_type
# NO INJURY / DRIVE AWAY              117376
# INJURY AND / OR TOW DUE TO CRASH     91930
# Name: count, dtype: int64

# %%
len(first_crash_types)
# Out:
# 2

# %%
trafficway_types = df.trafficway_type.value_counts()

# %%
trafficway_types
# Out:
# trafficway_type
# NOT DIVIDED                        77753
# FOUR WAY                           49057
# DIVIDED - W/MEDIAN (NOT RAISED)    34221
# ONE-WAY                            12341
# DIVIDED - W/MEDIAN BARRIER         10720
# T-INTERSECTION                      9233
# OTHER                               4757
# CENTER TURN LANE                    2862
# UNKNOWN INTERSECTION TYPE           1885
# FIVE POINT, OR MORE                 1119
# UNKNOWN                             1060
# Y-INTERSECTION                       958
# TRAFFIC ROUTE                        776
# ALLEY                                741
# NOT REPORTED                         581
# PARKING LOT                          448
# RAMP                                 375
# ROUNDABOUT                           149
# DRIVEWAY                             143
# L-INTERSECTION                       127
# Name: count, dtype: int64

# %%
len(trafficway_types)
# Out:
# 20

# %%
allignment_types = df.alignment.value_counts()

# %%
allignment_types
# Out:
# alignment
# STRAIGHT AND LEVEL       204590
# STRAIGHT ON GRADE          2992
# CURVE, LEVEL               1014
# STRAIGHT ON HILLCREST       478
# CURVE ON GRADE              179
# CURVE ON HILLCREST           53
# Name: count, dtype: int64

# %%
len(allignment_types)
# Out:
# 6

# %%
roadway_surface_conditions = df.roadway_surface_cond.value_counts()

# %%
roadway_surface_conditions
# Out:
# roadway_surface_cond
# DRY                155905
# WET                 32908
# UNKNOWN             12509
# SNOW OR SLUSH        6203
# ICE                  1303
# OTHER                 438
# SAND, MUD, DIRT        40
# Name: count, dtype: int64

# %%
len(roadway_surface_conditions)
# Out:
# 7

# %%
road_defect_conditions = df.road_defect.value_counts()

# %%
roadway_surface_conditions
# Out:
# roadway_surface_cond
# DRY                155905
# WET                 32908
# UNKNOWN             12509
# SNOW OR SLUSH        6203
# ICE                  1303
# OTHER                 438
# SAND, MUD, DIRT        40
# Name: count, dtype: int64

# %%
len(road_defect_conditions)
# Out:
# 7

# %%
crash_type_conditions = df.crash_type.value_counts()

# %%
crash_type_conditions
# Out:
# crash_type
# NO INJURY / DRIVE AWAY              117376
# INJURY AND / OR TOW DUE TO CRASH     91930
# Name: count, dtype: int64

# %%
len(crash_type_conditions)
# Out:
# 2

# %%
intersection_related_i_conditions = df.intersection_related_i.value_counts()

# %%
intersection_related_i_conditions
# Out:
# intersection_related_i
# Y    199324
# N      9982
# Name: count, dtype: int64

# %%
len(intersection_related_i_conditions)
# Out:
# 2

# %%
damage_conditions = df.damage.value_counts()

# %%
damage_conditions
# Out:
# damage
# OVER $1,500      147313
# $501 - $1,500     41210
# $500 OR LESS      20783
# Name: count, dtype: int64

# %%
len(damage_conditions)
# Out:
# 3

# %%
prim_contributory_cause_conditions = df.prim_contributory_cause.value_counts()

# %%
prim_contributory_cause_conditions
# Out:
# prim_contributory_cause
# UNABLE TO DETERMINE                                                                 58316
# FAILING TO YIELD RIGHT-OF-WAY                                                       42914
# FOLLOWING TOO CLOSELY                                                               19084
# DISREGARDING TRAFFIC SIGNALS                                                        14591
# IMPROPER TURNING/NO SIGNAL                                                          12643
# FAILING TO REDUCE SPEED TO AVOID CRASH                                              10676
# IMPROPER OVERTAKING/PASSING                                                          8302
# DISREGARDING STOP SIGN                                                               6749
# IMPROPER LANE USAGE                                                                  6462
# NOT APPLICABLE                                                                       5241
# ...

# %%
len(prim_contributory_cause_conditions)
# Out:
# 40

# %%
num_units_conditions = df.num_units.value_counts()

# %%
num_units_conditions
# Out:
# num_units
# 2     189366
# 3      12251
# 1       5123
# 4       1908
# 5        453
# 6        135
# 7         34
# 8         22
# 9          9
# 10         4
# 11         1
# Name: count, dtype: int64

# %%
len(num_units_conditions)
# Out:
# 11

# %%
most_severe_injury_conditions = df.most_severe_injury.value_counts()

# %%
most_severe_injury_conditions

# %%
len(most_severe_injury_conditions)

# %%
injuries_total_conditions = df.injuries_total.value_counts()

# %%
injuries_total_conditions
# Out:
# injuries_total
# 0.0     154789
# 1.0      38378
# 2.0      10447
# 3.0       3505
# 4.0       1338
# 5.0        488
# 6.0        212
# 7.0         80
# 8.0         30
# 9.0         14
# 10.0         7
# 11.0         5
# 15.0         4
# 12.0         3
# 21.0         2
# 16.0         1
# 17.0         1
# 19.0         1
# 13.0         1
# Name: count, dtype: int64

# %%
len(injuries_total_conditions)

# %%
injuries_fatal_conditions = df.injuries_fatal.value_counts()

# %%
injuries_fatal_conditions
# Out:
# injuries_fatal
# 0.0    208955
# 1.0       317
# 2.0        30
# 3.0         4
# Name: count, dtype: int64

# %%
len(injuries_fatal_conditions)

# %%
injuries_incapacitating_conditions = df.injuries_incapacitating.value_counts()

# %%
injuries_incapacitating_conditions

# %%
len(injuries_incapacitating_conditions)

# %%
injuries_nonincapacitating_conditions = df.injuries_non_incapacitating.value_counts()

# %%
injuries_nonincapacitating_conditions
# Out:
# injuries_non_incapacitating
# 0.0     176306
# 1.0      24413
# 2.0       5688
# 3.0       1828
# 4.0        667
# 5.0        232
# 6.0        106
# 7.0         33
# 8.0         15
# 10.0         5
# 9.0          5
# 14.0         1
# 19.0         1
# 18.0         1
# 21.0         1
# 12.0         1
# 11.0         1
# 16.0         1
# 13.0         1
# Name: count, dtype: int64

# %%
len(injuries_nonincapacitating_conditions)

# %%
injuries_reported_not_evident_conditions = df.injuries_reported_not_evident.value_counts()

# %%
injuries_reported_not_evident_conditions

# %%
len(injuries_reported_not_evident_conditions)

# %%
injuries_no_indication_conditions = df.injuries_no_indication.value_counts()

# %%
injuries_no_indication_conditions

# %%
len(injuries_no_indication_conditions)

# %%
crash_hour_conditions = df.crash_hour.value_counts()

# %%
crash_hour_conditions

# %%
len(crash_hour_conditions)

# %%
crash_day_of_week_conditions = df.crash_day_of_week.value_counts()

# %%
crash_day_of_week_conditions

# %%
len(crash_day_of_week_conditions)

# %%
crash_month_conditions = df.crash_month.value_counts()

# %%
crash_month_conditions

# %%
len(crash_month_conditions)
